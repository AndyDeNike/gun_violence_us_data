# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import locale

# %%
df = pd.read_csv('data/gun-violence-data_01-2013_03-2018.csv')

# %%
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
df.head(3)
# Out:
#    incident_id        date         state city_or_county  \
# 0       461105  2013-01-01  Pennsylvania     Mckeesport
# 1       460726  2013-01-01    California      Hawthorne
# 2       478855  2013-01-01          Ohio         Lorain
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
#
# ...

# %%
#Indexing: Single Rows

#The simplest way to access a row is to pass the row number to the .iloc method. Note that first row is zero, just 
#like list indexes.

# %%
df.iloc[1]
# Out:
# incident_id                                                               460726
# date                                                                  2013-01-01
# state                                                                 California
# city_or_county                                                         Hawthorne
# address                                             13500 block of Cerise Avenue
# n_killed                                                                       1
# n_injured                                                                      3
# incident_url                   http://www.gunviolencearchive.org/incident/460726
# source_url                     http://www.dailybulletin.com/article/zz/201301...
# incident_url_fields_missing                                                False
# congressional_district                                                        43
# gun_stolen                                                                   NaN
# ...

# %%
#Indexing: Multiple Rows

#If we need multiple rows, we can pass in multiple index values. Note that this changes the order of the results!

#loc gets rows (or columns) with particular labels from the index.
#iloc gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
df.loc[[2, 3, 44]] #iloc and loc have the same search parameters because the index is named as a number (in this case)
# Out:
#     incident_id        date       state   city_or_county  \
# 2        478855  2013-01-01        Ohio           Lorain
# 3        478925  2013-01-05    Colorado           Aurora
# 44       483835  2013-03-30  California  Merced (county)
#
#                              address  n_killed  n_injured  \
# 2              1776 East 28th Street         1          3
# 3   16000 block of East Ithaca Place         4          0
# 44  9200 block of Westside Boulevard         3          2
#
#                                          incident_url  \
# 2   http://www.gunviolencearchive.org/incident/478855
# 3   http://www.gunviolencearchive.org/incident/478925
# 44  http://www.gunviolencearchive.org/incident/483835
#
#                                            source_url  \
# 2   http://chronicle.northcoastnow.com/2013/02/14/...
# 3   http://www.dailydemocrat.com/20130106/aurora-s...
# 44     http://www.sacbee.com/news/article2604101.html
#
# ...

# %%
df.loc[df['state'] == 'California']
# Out:
#         incident_id        date       state    city_or_county  \
# 1            460726  2013-01-01  California         Hawthorne
# 8            479389  2013-01-21  California         Brentwood
# 16           479580  2013-02-03  California     Yuba (county)
# 19           480311  2013-02-11  California           Vallejo
# 22           480358  2013-02-19  California   Orange (county)
# 25           480407  2013-02-23  California         Lancaster
# 30           481213  2013-03-04  California         Los Banos
# 35           482801  2013-03-13  California         Oceanside
# 37           482838  2013-03-14  California           Modesto
# 38           482926  2013-03-16  California              Galt
# 39           482934  2013-03-17  California          Stockton
# 44           483835  2013-03-30  California   Merced (county)
# 48           483878  2013-04-07  California        Long Beach
# 50           484279  2013-04-10  California           Vallejo
# ...

# %%
#Slicing the dataframe just as if it were a list also works.

# %%
df[:3]
# Out:
#    incident_id        date         state city_or_county  \
# 0       461105  2013-01-01  Pennsylvania     Mckeesport
# 1       460726  2013-01-01    California      Hawthorne
# 2       478855  2013-01-01          Ohio         Lorain
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
#
# ...

# %%
df[3:6]
# Out:
#    incident_id        date           state city_or_county  \
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
# 5       478948  2013-01-07        Oklahoma          Tulsa
#
#                             address  n_killed  n_injured  \
# 3  16000 block of East Ithaca Place         4          0
# 4         307 Mourning Dove Terrace         2          2
# 5        6000 block of South Owasso         4          0
#
#                                         incident_url  \
# 3  http://www.gunviolencearchive.org/incident/478925
# 4  http://www.gunviolencearchive.org/incident/478959
# 5  http://www.gunviolencearchive.org/incident/478948
#
#                                           source_url  \
# 3  http://www.dailydemocrat.com/20130106/aurora-s...
# 4  http://www.journalnow.com/news/local/article_d...
# 5  http://usnews.nbcnews.com/_news/2013/01/07/163...
#
#    incident_url_fields_missing          ...           \
# ...

# %%
#Indexing: Columns

#We can access a subset of the columns in a dataframe by placing the list of columns in brackets like so:

# %%
df['state'].head(3)   #df.State.head(3)  alternative .notation
# Out:
# 0    Pennsylvania
# 1      California
# 2            Ohio
# Name: state, dtype: object

# %%
df.columns
# Out:
# Index([u'incident_id', u'date', u'state', u'city_or_county', u'address',
#        u'n_killed', u'n_injured', u'incident_url', u'source_url',
#        u'incident_url_fields_missing', u'congressional_district',
#        u'gun_stolen', u'gun_type', u'incident_characteristics', u'latitude',
#        u'location_description', u'longitude', u'n_guns_involved', u'notes',
#        u'participant_age', u'participant_age_group', u'participant_gender',
#        u'participant_name', u'participant_relationship', u'participant_status',
#        u'participant_type', u'sources', u'state_house_district',
#        u'state_senate_district'],
#       dtype='object')

# %%
#Indexing: Columns and Rows¶

#If we need to subset by both columns and rows, you can stack the commands we've already learned.

# %%
df[['state','n_killed']][:10]
# Out:
#             state  n_killed
# 0    Pennsylvania         0
# 1      California         1
# 2            Ohio         1
# 3        Colorado         4
# 4  North Carolina         2
# 5        Oklahoma         4
# 6      New Mexico         5
# 7       Louisiana         0
# 8      California         0
# 9        Maryland         1

# %%
#Indexing: Scalar Values

#As you may have noticed, everything we've tried so far returns a small dataframe or series. If you need a single 
#value, simply pass in a single column and index value.

# %%
df.state.iloc[2]
# Out:
# 'Ohio'

# %%
(df['state'] == 'California').head(4)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: state, dtype: bool

# %%
#We get a series of the results of the boolean. Passing that series into a dataframe gives us the subset of the 
#dataframe where the boolean evaluates to True.

# %%
df[df['state'] == 'California']
# Out:
#         incident_id        date       state    city_or_county  \
# 1            460726  2013-01-01  California         Hawthorne
# 8            479389  2013-01-21  California         Brentwood
# 16           479580  2013-02-03  California     Yuba (county)
# 19           480311  2013-02-11  California           Vallejo
# 22           480358  2013-02-19  California   Orange (county)
# 25           480407  2013-02-23  California         Lancaster
# 30           481213  2013-03-04  California         Los Banos
# 35           482801  2013-03-13  California         Oceanside
# 37           482838  2013-03-14  California           Modesto
# 38           482926  2013-03-16  California              Galt
# 39           482934  2013-03-17  California          Stockton
# 44           483835  2013-03-30  California   Merced (county)
# 48           483878  2013-04-07  California        Long Beach
# 50           484279  2013-04-10  California           Vallejo
# ...

# %%
#Some of the logical operators are different:
    #~ replaces not
    #| replaces or
    #& replaces and
#If you have multiple arguments they'll need to be wrapped in parentheses. For example:

# %%
df[(df.n_killed > 5) & (df.state == 'California')]
# Out:
#         incident_id        date       state  city_or_county  \
# 95           489581  2013-06-07  California    Santa Monica
# 101531       456893  2015-12-02  California  San Bernardino
# 218580       987611  2017-11-14  California         Corning
#
#                            address  n_killed  n_injured  \
# 95              2036 Yorkshire Ave         6          1
# 101531  1365 South Waterman Avenue        16         19
# 218580         17357 Stagecoach Rd         6         12
#
#                                              incident_url  \
# 95      http://www.gunviolencearchive.org/incident/489581
# 101531  http://www.gunviolencearchive.org/incident/456893
# 218580  http://www.gunviolencearchive.org/incident/987611
#
#                                                source_url  \
# 95      http://www.huffingtonpost.com/2013/06/07/santa...
# 101531  http://www.latimes.com/local/lanow/la-me-ln-sa...
# 218580  http://www.times-standard.com/general-news/201...
#
# ...

# %%
df[df.state.isin(['California', 'Oregon', 'Washington'])]
# Out:
#         incident_id        date       state            city_or_county  \
# 1            460726  2013-01-01  California                 Hawthorne
# 8            479389  2013-01-21  California                 Brentwood
# 16           479580  2013-02-03  California             Yuba (county)
# 19           480311  2013-02-11  California                   Vallejo
# 22           480358  2013-02-19  California           Orange (county)
# 25           480407  2013-02-23  California                 Lancaster
# 30           481213  2013-03-04  California                 Los Banos
# 35           482801  2013-03-13  California                 Oceanside
# 37           482838  2013-03-14  California                   Modesto
# 38           482926  2013-03-16  California                      Galt
# 39           482934  2013-03-17  California                  Stockton
# 44           483835  2013-03-30  California           Merced (county)
# ...

# %%
#Less Common Methods

#Pandas offers many more indexing methods. You should probably stick to a few of them for the sake of keeping your code readable, but it's worth knowing they exist in case you need to read other people's code or have an unusual use case:

    #There are other ways to slice data with brackets. For the sake of readability, please don't use of them.
    #.at and .iat: like .loc and .iloc but much faster in exchange for only working on a single column and only 
    #returning a single result.
    #.eval: fast evaluation of a limited set of simple operators. .query works by calling this.
    #.ix: deprecated method that tried to determine if an index should be evaluated with .loc or .iloc. This led to a 
    #lot of subtle bugs! If you see this, you're looking at old code that won't work any more.
    #.get: like .loc, but will return a default value if the key doesn't exist in the index. Only works on a single 
    #column/series.
    #.lookup: Not recommended. It's in the documentation, but it's unclear if this is actually still supported.
    #.mask: like boolean indexing, but returns a dataframe/series of the same size as the original and anywhere that 
    #the boolean evaluates to True is set to nan.
    #.query: similar to boolean indexing. Faster for large dataframes. Only supports a restricted set of operations; 
    #don't use if you need isnull() or other dataframe methods.
    #.take: equivalent to .iloc, but can operate on either rows or columns.
    #.where: like boolean indexing, but returns a dataframe/series of the same size as the original and anywhere that 
    #the boolean evaluates to False is set to nan.
    #Multi-indexing: potentially useful for small to mid sized heirarchical datasets. Slow on larger datasets.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
# incident_id                    239677 non-null int64
# date                           239677 non-null object
# state                          239677 non-null object
# city_or_county                 239677 non-null object
# address                        223180 non-null object
# n_killed                       239677 non-null int64
# n_injured                      239677 non-null int64
# incident_url                   239677 non-null object
# source_url                     239209 non-null object
# incident_url_fields_missing    239677 non-null bool
# congressional_district         227733 non-null float64
# gun_stolen                     140179 non-null object
# gun_type                       140226 non-null object
# incident_characteristics       239351 non-null object
# latitude                       231754 non-null float64
# ...

# %%
#number of incidents in each state 

df['state'].value_counts()
# Out:
# Illinois                17556
# California              16306
# Florida                 15029
# Texas                   13577
# Ohio                    10244
# New York                 9712
# Pennsylvania             8929
# Georgia                  8925
# North Carolina           8739
# Louisiana                8103
# Tennessee                7626
# South Carolina           6939
# Missouri                 6631
# Michigan                 6136
# Massachusetts            5981
# Virginia                 5949
# Indiana                  5852
# Maryland                 5798
# Alabama                  5471
# New Jersey               5387
# Wisconsin                4787
# Kentucky                 4157
# Mississippi              3599
# Oklahoma                 3455
# Washington               3434
# Colorado                 3201
# District of Columbia     3195
# Connecticut              3067
# Arkansas                 2842
# Iowa                     2517
# Minnesota                2408
# ...

# %%
df['state'].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#         incident_id       n_killed      n_injured  congressional_district  \
# count  2.396770e+05  239677.000000  239677.000000           227733.000000
# mean   5.593343e+05       0.252290       0.494007                8.001265
# std    2.931287e+05       0.521779       0.729952                8.480835
# min    9.211400e+04       0.000000       0.000000                0.000000
# 25%    3.085450e+05       0.000000       0.000000                2.000000
# 50%    5.435870e+05       0.000000       0.000000                5.000000
# 75%    8.172280e+05       0.000000       1.000000               10.000000
# max    1.083472e+06      50.000000      53.000000               53.000000
#
#             latitude      longitude  n_guns_involved  state_house_district  \
# count  231754.000000  231754.000000    140226.000000         200905.000000
# mean       37.546598     -89.338348         1.372442             55.447132
# std         5.130763      14.359546         4.678202             42.048117
# ...

# %%
df['n_killed'].groupby(df['state']).sum().sort_values(ascending=False)

#total killed in each state 
#funcitonally the same as         df.groupby('state')['n_killed'].sum()
# Out:
# state
# California              5562
# Texas                   5046
# Florida                 3909
# Illinois                3409
# Ohio                    2508
# Georgia                 2456
# Pennsylvania            2395
# North Carolina          2225
# Louisiana               2179
# Missouri                2136
# Alabama                 1880
# Tennessee               1824
# New York                1705
# Maryland                1691
# South Carolina          1610
# Indiana                 1608
# Michigan                1588
# Virginia                1459
# Mississippi             1176
# New Jersey              1168
# Arizona                 1094
# Kentucky                1066
# Oklahoma                 941
# Wisconsin                862
# Washington               853
# Nevada                   799
# Colorado                 796
# Arkansas                 773
# Kansas                   542
# New Mexico               495
# Massachusetts            472
# Minnesota                461
# ...

# %%
df['n_killed'].count()
# Out:
# 239677

# %%
df['n_injured'].count()
# Out:
# 239677

# %%
df['n_killed'].sum()
# Out:
# 60468

# %%
df['n_injured'].sum()
# Out:
# 118402

# %%
df.columns
# Out:
# Index([u'incident_id', u'date', u'state', u'city_or_county', u'address',
#        u'n_killed', u'n_injured', u'incident_url', u'source_url',
#        u'incident_url_fields_missing', u'congressional_district',
#        u'gun_stolen', u'gun_type', u'incident_characteristics', u'latitude',
#        u'location_description', u'longitude', u'n_guns_involved', u'notes',
#        u'participant_age', u'participant_age_group', u'participant_gender',
#        u'participant_name', u'participant_relationship', u'participant_status',
#        u'participant_type', u'sources', u'state_house_district',
#        u'state_senate_district'],
#       dtype='object')

# %%
plt.figure(figsize=(75,8))
sns.countplot(x='state', data=df)

# %%
df['participant_age'].value_counts()  #such general range may not give
#meaningful, detailed results
# Out:
# 0::24                                                                           3814
# 0::23                                                                           3735
# 0::22                                                                           3733
# 0::19                                                                           3719
# 0::21                                                                           3612
# 0::18                                                                           3536
# 0::20                                                                           3535
# 0::25                                                                           3500
# 0::26                                                                           3277
# 0::27                                                                           3110
# 0::28                                                                           2719
# ...

# %%
df['n_killed'].value_counts()  #the amount of those killed per record (Row)
# Out:
# 0     185835
# 1      48436
# 2       4604
# 3        595
# 4        139
# 5         41
# 6         11
# 8          5
# 9          3
# 7          2
# 50         1
# 27         1
# 17         1
# 16         1
# 11         1
# 10         1
# Name: n_killed, dtype: int64

# %%
df['participant_type'].value_counts()
# Out:
# 0::Victim                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
# ...

# %%
df['gun_type'].value_counts()  #gun type counts
# Out:
# 0::Unknown                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
df['gun_stolen'].value_counts()
# Out:
# 0::Unknown                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
plt.figure(figsize=(75,8))   #how many killed per state 
sns.barplot(x='state', y='n_killed', data=df, estimator=np.sum)

# %%
df['population_2010'] = ''

# %%
df['population_2017'] = ''

# %%
df
# Out:
#         incident_id        date                 state  \
# 0            461105  2013-01-01          Pennsylvania
# 1            460726  2013-01-01            California
# 2            478855  2013-01-01                  Ohio
# 3            478925  2013-01-05              Colorado
# 4            478959  2013-01-07        North Carolina
# 5            478948  2013-01-07              Oklahoma
# 6            479363  2013-01-19            New Mexico
# 7            479374  2013-01-21             Louisiana
# 8            479389  2013-01-21            California
# 9            492151  2013-01-23              Maryland
# 10           491674  2013-01-23             Tennessee
# 11           479413  2013-01-25              Missouri
# 12           479561  2013-01-26             Louisiana
# 13           479554  2013-01-26  District of Columbia
# 14           479460  2013-01-26                  Ohio
# 15           479573  2013-02-02             Tennessee
# ...

# %%
#df = pd.to_numeric(df['population_2010'], errors='coerce')

# %%
#population_2010

df.loc[df['state'] == 'California', 'population_2010'] = '37,253,956'  
df.loc[df['state'] == 'Illinois', 'population_2010'] = '12,830,632'  
df.loc[df['state'] == 'Florida', 'population_2010'] = '18,801,310' 
df.loc[df['state'] == 'Texas', 'population_2010'] = '25,145,561' 
df.loc[df['state'] == 'Ohio', 'population_2010'] = '11,536,504' 
df.loc[df['state'] == 'New York', 'population_2010'] = '19,378,102' 
df.loc[df['state'] == 'Pennsylvania', 'population_2010'] = '12,702,379' 
df.loc[df['state'] == 'North Carolina', 'population_2010'] = '9,535,483' 
df.loc[df['state'] == 'Louisiana', 'population_2010'] = '4,533,372' 
df.loc[df['state'] == 'Tennessee', 'population_2010'] = '6,346,105' 
df.loc[df['state'] == 'South Carolina', 'population_2010'] = '4,625,364' 
df.loc[df['state'] == 'Missouri', 'population_2010'] = '5,988,927'
df.loc[df['state'] == 'Michigan', 'population_2010'] = '9,883,640'
df.loc[df['state'] == 'Massachusetts', 'population_2010'] = '6,547,629' 
df.loc[df['state'] == 'Virginia', 'population_2010'] = '8,001,024' 
df.loc[df['state'] == 'Indiana', 'population_2010'] = '6,483,802' 
df.loc[df['state'] == 'Maryland', 'population_2010'] = '5,773,552' 
df.loc[df['state'] == 'Alabama', 'population_2010'] = '4,779,736' 
df.loc[df['state'] == 'New Jersey', 'population_2010'] = '8,791,894' 
df.loc[df['state'] == 'Kentucky', 'population_2010'] = '4,339,367' 
df.loc[df['state'] == 'Wisconsin', 'population_2010'] = '5,686,986' 
df.loc[df['state'] == 'Mississippi', 'population_2010'] = '2,967,297' 
df.loc[df['state'] == 'Oklahoma', 'population_2010'] = '3,751,351' 
df.loc[df['state'] == 'Washington', 'population_2010'] = '6,724,540' 
df.loc[df['state'] == 'Colorado', 'population_2010'] = '5,029,196' 
df.loc[df['state'] == 'District of Columbia', 'population_2010'] = '601,723' 
df.loc[df['state'] == 'Connecticut', 'population_2010'] = '3,574,097' 
df.loc[df['state'] == 'Arkansas', 'population_2010'] = '2,915,918' 
df.loc[df['state'] == 'Iowa', 'population_2010'] = '3,046,355' 
df.loc[df['state'] == 'Arizona', 'population_2010'] = '6,392,017' 
df.loc[df['state'] == 'Oregon', 'population_2010'] = '3,831,074' 
df.loc[df['state'] == 'Kansas', 'population_2010'] = '2,853,118'
df.loc[df['state'] == 'Nevada', 'population_2010'] = '2,700,551' 
df.loc[df['state'] == 'Delaware', 'population_2010'] = '897,934' 
df.loc[df['state'] == 'Nebraska', 'population_2010'] = '1,826,341' 
df.loc[df['state'] == 'New Mexico', 'population_2010'] = '2,059,179' 
df.loc[df['state'] == 'West Virginia', 'population_2010'] = '1,852,994' 
df.loc[df['state'] == 'Alaska', 'population_2010'] = '710,231' 
df.loc[df['state'] == 'Utah', 'population_2010'] = '2,763,885' 
df.loc[df['state'] == 'New Hampshire', 'population_2010'] = '1,316,470' 
df.loc[df['state'] == 'Maine', 'population_2010'] = '1,328,361' 
df.loc[df['state'] == 'Rhode Island', 'population_2010'] = '1,052,567' 
df.loc[df['state'] == 'Idaho', 'population_2010'] = '1,567,582' 
df.loc[df['state'] == 'Montana', 'population_2010'] = '989,415' 
df.loc[df['state'] == 'North Dakota', 'population_2010'] = '672,591' 
df.loc[df['state'] == 'South Dakota', 'population_2010'] = '814,180' 
df.loc[df['state'] == 'Wyoming', 'population_2010'] = '563,626'  
df.loc[df['state'] == 'Vermont', 'population_2010'] = '625,741' 
df.loc[df['state'] == 'Hawaii', 'population_2010'] = '1,360,301'   
df.loc[df['state'] == 'Georgia', 'population_2010'] = '9,687,653' 
df.loc[df['state'] == 'Minnesota', 'population_2010'] = '5,576,606' 

#population_2017

df.loc[df['state'] == 'California', 'population_2017'] = '39,536,653'
df.loc[df['state'] == 'Illinois', 'population_2017'] = '12,802,023'
df.loc[df['state'] == 'Florida', 'population_2017'] = '20,984,400'
df.loc[df['state'] == 'Texas', 'population_2017'] = '28,304,596' 
df.loc[df['state'] == 'Ohio', 'population_2017'] = '11,658,609' 
df.loc[df['state'] == 'New York', 'population_2017'] = '19,849,399' 
df.loc[df['state'] == 'Pennsylvania', 'population_2017'] = '12,805,537' 
df.loc[df['state'] == 'North Carolina', 'population_2017'] = '10,273,419' 
df.loc[df['state'] == 'Louisiana', 'population_2017'] = '4,684,333' 
df.loc[df['state'] == 'Tennessee', 'population_2017'] = '6,715,984' 
df.loc[df['state'] == 'South Carolina', 'population_2017'] = '5,024,369' 
df.loc[df['state'] == 'Missouri', 'population_2017'] = '6,113,532' 
df.loc[df['state'] == 'Michigan', 'population_2017'] = '9,962,311' 
df.loc[df['state'] == 'Massachusetts', 'population_2017'] = '6,859,819' 
df.loc[df['state'] == 'Virginia', 'population_2017'] = '8,470,020' 
df.loc[df['state'] == 'Indiana', 'population_2017'] = '6,666,818'
df.loc[df['state'] == 'Maryland', 'population_2017'] = '6,052,177'
df.loc[df['state'] == 'Alabama', 'population_2017'] = '4,874,747' 
df.loc[df['state'] == 'New Jersey', 'population_2017'] = '9,005,644' 
df.loc[df['state'] == 'Kentucky', 'population_2017'] = '4,454,189' 
df.loc[df['state'] == 'Wisconsin', 'population_2017'] = '5,795,483' 
df.loc[df['state'] == 'Mississippi', 'population_2017'] = '2,984,100' 
df.loc[df['state'] == 'Oklahoma', 'population_2017'] = '3,930,864' 
df.loc[df['state'] == 'Washington', 'population_2017'] = '7,405,743' 
df.loc[df['state'] == 'Colorado', 'population_2017'] = '5,607,154'  
df.loc[df['state'] == 'District of Columbia', 'population_2017'] = '693,972' 
df.loc[df['state'] == 'Connecticut', 'population_2017'] = '3,588,184' 
df.loc[df['state'] == 'Arkansas', 'population_2017'] = '3,004,279' 
df.loc[df['state'] == 'Iowa', 'population_2017'] = '3,145,711' 
df.loc[df['state'] == 'Arizona', 'population_2017'] = '7,016,270' 
df.loc[df['state'] == 'Oregon', 'population_2017'] = '4,142,776'
df.loc[df['state'] == 'Kansas', 'population_2017'] = '2,913,123'
df.loc[df['state'] == 'Nevada', 'population_2017'] = '2,998,039'
df.loc[df['state'] == 'Delaware', 'population_2017'] = '961,939'
df.loc[df['state'] == 'Nebraska', 'population_2017'] = '1,920,076'
df.loc[df['state'] == 'New Mexico', 'population_2017'] = '2,088,070'
df.loc[df['state'] == 'West Virginia', 'population_2017'] = '1,815,857' 
df.loc[df['state'] == 'Alaska', 'population_2017'] = '739,795' 
df.loc[df['state'] == 'Utah', 'population_2017'] = '3,101,833'
df.loc[df['state'] == 'New Hampshire', 'population_2017'] = '1,342,795'
df.loc[df['state'] == 'Maine', 'population_2017'] = '1,335,907' 
df.loc[df['state'] == 'Rhode Island', 'population_2017'] = '1,059,639' 
df.loc[df['state'] == 'Idaho', 'population_2017'] = '1,716,943' 
df.loc[df['state'] == 'Montana', 'population_2017'] = '1,050,493'
df.loc[df['state'] == 'North Dakota', 'population_2017'] = '755,393' 
df.loc[df['state'] == 'South Dakota', 'population_2017'] = '869,666' 
df.loc[df['state'] == 'Wyoming', 'population_2017'] = '579,315' 
df.loc[df['state'] == 'Vermont', 'population_2017'] = '623,657' 
df.loc[df['state'] == 'Hawaii', 'population_2017'] = '1,427,538' 
df.loc[df['state'] == 'Georgia', 'population_2017'] = '10,429,379' 
df.loc[df['state'] == 'Minnesota', 'population_2017'] = '5,303,925'

# %%
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8' )

df['population_2010'] = df['population_2010'].apply(locale.atoi)
df['population_2017'] = df['population_2017'].apply(locale.atoi)
#df['population_2010'] = df['population_2010'].apply(locale.atof)  
#df['population_2010'] = df.population_2010.astype(int)
#df['population_2010'] = pd.to_numeric(df['population_2010'], errors='coerce')

# %%
#df['population_2010'] = pd.to_numeric(df['population_2010'], errors='coerce')
#df['population_2017'] = pd.to_numeric(df['population_2017'], errors='coerce')

#df['population_2010'] = df.population_2010.astype(int)

# %%
df.head(10)
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
# 5       478948  2013-01-07        Oklahoma          Tulsa
# 6       479363  2013-01-19      New Mexico    Albuquerque
# 7       479374  2013-01-21       Louisiana    New Orleans
# 8       479389  2013-01-21      California      Brentwood
# 9       492151  2013-01-23        Maryland      Baltimore
#
#                                              address  n_killed  n_injured  \
# 0          1506 Versailles Avenue and Coursin Street         0          4
# 1                       13500 block of Cerise Avenue         1          3
# 2                              1776 East 28th Street         1          3
# ...

# %%
df.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# gun_stolen                      object
# gun_type                        object
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_name                object
# participant_relationship        object
# ...

# %%
plt.figure(figsize=(75,8))   #how many killed per state 
sns.barplot(x='state', y='population_2017', data=df, estimator=np.sum)

# %%
#total damage (killed and injured)

# %%
df["total_damage"] = df['n_killed'] + df['n_injured']

# %%
df.head(3)
# Out:
#    incident_id        date         state city_or_county  \
# 0       461105  2013-01-01  Pennsylvania     Mckeesport
# 1       460726  2013-01-01    California      Hawthorne
# 2       478855  2013-01-01          Ohio         Lorain
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
#
# ...

# %%
#seperation of data based on years

df["year"] = [each.split("-")[0] for each in df.date]

# %%
df.head(3)
# Out:
#    incident_id        date         state city_or_county  \
# 0       461105  2013-01-01  Pennsylvania     Mckeesport
# 1       460726  2013-01-01    California      Hawthorne
# 2       478855  2013-01-01          Ohio         Lorain
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
#
# ...
